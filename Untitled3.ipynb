# %%
#preprocessing phase
import pandas as pd
import seaborn as sns
dataset = pd.read_csv("kc_house_data.csv")
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataset['sqft_living'] == dataset['sqft_above'] + dataset['sqft_basement']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 21608    True
# 21609    True
# 21610    True
# 21611    True
# 21612    True
# Length: 21613, dtype: bool

# %%
dataset.drop(['date','id','zipcode','lat','long','sqft_living'], axis = 1, inplace = True)
dataset
#J'ai supprimé les colonnes dates, id, zipcode, lat et long parce que j'estimais qu'elles n'etaient pas importantes, donc elles ne devaient pas necessairement apparaitre dans ma dat
# Out:
#           price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 0      221900.0         3       1.00      5650     1.0           0     0
# 1      538000.0         3       2.25      7242     2.0           0     0
# 2      180000.0         2       1.00     10000     1.0           0     0
# 3      604000.0         4       3.00      5000     1.0           0     0
# 4      510000.0         3       2.00      8080     1.0           0     0
# ...         ...       ...        ...       ...     ...         ...   ...
# 21608  360000.0         3       2.50      1131     3.0           0     0
# 21609  400000.0         4       2.50      5813     2.0           0     0
# 21610  402101.0         2       0.75      1350     2.0           0     0
# 21611  400000.0         3       2.50      2388     2.0           0     0
# 21612  325000.0         2       0.75      1076     2.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
dataset.describe()
# Out:
#               price      bedrooms     bathrooms      sqft_lot        floors  \
# count  2.161300e+04  21613.000000  21613.000000  2.161300e+04  21613.000000
# mean   5.400881e+05      3.370842      2.114757  1.510697e+04      1.494309
# std    3.671272e+05      0.930062      0.770163  4.142051e+04      0.539989
# min    7.500000e+04      0.000000      0.000000  5.200000e+02      1.000000
# 25%    3.219500e+05      3.000000      1.750000  5.040000e+03      1.000000
# 50%    4.500000e+05      3.000000      2.250000  7.618000e+03      1.500000
# 75%    6.450000e+05      4.000000      2.500000  1.068800e+04      2.000000
# max    7.700000e+06     33.000000      8.000000  1.651359e+06      3.500000
#
#          waterfront          view     condition         grade    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430      7.656873   1788.390691
# ...

# %%
dataset = dataset[dataset['bedrooms'] < 10]
dataset = dataset[dataset['bathrooms'] < 6.5]
dataset = dataset[dataset['sqft_above'] < 10000]
dataset = dataset[dataset['sqft_basement'] < 10000]
dataset = dataset[dataset['sqft_lot'] < 1.5e6]
dataset = dataset[dataset['floors'] < 3.25]
dataset = dataset[dataset['grade'] < 12]
dataset = dataset[dataset['sqft_living15'] < 6000]
dataset = dataset[dataset['sqft_lot15'] < 600000]
dataset
# Out:
#           price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 0      221900.0         3       1.00      5650     1.0           0     0
# 1      538000.0         3       2.25      7242     2.0           0     0
# 2      180000.0         2       1.00     10000     1.0           0     0
# 3      604000.0         4       3.00      5000     1.0           0     0
# 4      510000.0         3       2.00      8080     1.0           0     0
# ...         ...       ...        ...       ...     ...         ...   ...
# 21608  360000.0         3       2.50      1131     3.0           0     0
# 21609  400000.0         4       2.50      5813     2.0           0     0
# 21610  402101.0         2       0.75      1350     2.0           0     0
# 21611  400000.0         3       2.50      2388     2.0           0     0
# 21612  325000.0         2       0.75      1076     2.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

y = dataset['price'].values
x = dataset.drop('price', axis=1).values
x_train, x_test, y_train,  y_test = train_test_split(x, y, test_size=0.20, random_state=30)
model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 38515386070.33819
# R squared 0.6451443279531645

# %%
sns.pairplot(dataset)

# %%
dd = (dataset['sqft_lot'] - dataset['sqft_lot'].mean())/dataset['sqft_lot'].std()

# %%
dd.describe()
# Out:
# count    2.149200e+04
# mean     1.954307e-16
# std      1.000000e+00
# min     -3.712306e-01
# 25%     -2.535916e-01
# 50%     -1.870032e-01
# 75%     -1.093276e-01
# max      2.993055e+01
# Name: sqft_lot, dtype: float64
